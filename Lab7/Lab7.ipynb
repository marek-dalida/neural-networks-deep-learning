# %%
import numpy as np

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def relu(x):
    return x * (x > 0)

def tanh(x):
    return np.tanh(x)

def calc_activation(x, weights, activation_func):
    activations = []
    activation = x
    for idx, w in enumerate(weights):
        z = np.dot(w, activation)
        activation = activation_func(z)
        activations.append(activation)
    return activations

# %% [markdown]
# ### Subtask 1

# %%
data_size = 500
neurons_per_layer = 500

# %%
weights = [
    np.full((neurons_per_layer, data_size), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0),
    np.full((neurons_per_layer, neurons_per_layer), 0)
]

# %%
# generate data with gaussian distribution
mu, sigma = 0, 1  # mean and standard deviation

sample = np.random.normal(mu, sigma, data_size)

# %%
import matplotlib.pyplot as plt

# generated data with gaussian distribution
count, bins, ignored = plt.hist(sample, 30, density=True)

plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *

               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),

         linewidth=2, color='r')

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("Weights init to 0 function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))

# %%
small_weight_mul = 0.00000001
weights = [
    np.random.randn(neurons_per_layer, data_size) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * small_weight_mul
]



activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("Small weights function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))

# %%
big_weight_mul = 100
weights = [
    np.random.randn(neurons_per_layer, data_size) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul,
    np.random.randn(neurons_per_layer, neurons_per_layer) * big_weight_mul
]


activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("Weights big function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))
# Out:
# <ipython-input-2-de792903a688>:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))

# %%
#Xavier initialization
lower, upper = -(1.0 / np.sqrt(neurons_per_layer)), (1.0 / np.sqrt(neurons_per_layer))

weights = [
    lower + np.random.randn(neurons_per_layer, data_size) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower)
]


activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("Xavier initialization function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))

# %%
#Normalized Xavier initialization
n_prev_layer = 500
n_next_layer = 500
lower, upper = -(np.sqrt(6.0) / np.sqrt(n_prev_layer + n_next_layer)), (np.sqrt(6.0) / np.sqrt(n_prev_layer + n_next_layer))

weights = [
    lower + np.random.randn(neurons_per_layer, data_size) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower),
    lower + np.random.randn(neurons_per_layer, neurons_per_layer) * (upper - lower)
]


activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("Normalized Xavier initialization function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))

# %%
#He initialization

weights = [
    np.random.randn(neurons_per_layer, data_size) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer),
    np.random.randn(neurons_per_layer, neurons_per_layer) * np.sqrt(2./neurons_per_layer)
]


activations_func = {'sigmoid': sigmoid, 'relu': relu, 'tanh': tanh}
for func_name in activations_func:
    activations = calc_activation(sample, weights, activations_func[func_name])
    fig, axs = plt.subplots(1, 10)
    fig.set_size_inches(18.5, 10.5)
    fig.suptitle("He initialization, activation function {}".format(func_name), fontsize=16)
    for i in range(10):
        axs[i].hist(activations[i])
        axs[i].set_title("Layer {}".format(i+1))

# %% [markdown]
# ### Subtask 2

# %%
import tensorflow as tf

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data(path="mnist.npz")

input_size = len(x_train[0]) * len(x_train[0][0])
hidden_layer_nodes = 32
output_size = 10

weights = [
    np.random.randn(hidden_layer_nodes, input_size) * np.sqrt(1 / input_size),
    np.random.randn(hidden_layer_nodes, hidden_layer_nodes) * np.sqrt(1 / hidden_layer_nodes),
    np.random.randn(output_size, hidden_layer_nodes) * np.sqrt(1 / hidden_layer_nodes)
]

biases = [
    np.random.randn(hidden_layer_nodes),
    np.random.randn(hidden_layer_nodes),
    np.random.randn(output_size)]

dropout_rate = [1, 0.5, 0.5]

# %%
def sigmoid(x):
    x = np.clip(x, -500, 500)
    return 1 / (1 + np.exp(-x))


def der_sigmoid(x):
    return sigmoid(x) * (1 - sigmoid(x))


def relu(x):
    return x * (x > 0)


def der_relu(x):
    return 1. * (x > 0)


def softmax(x):
    b = x.max()
    y = np.exp(x - b)
    return y / y.sum()


def cross_entropy_loss(y, yHat):
    return -np.sum(y * np.log(yHat))


def mean_squared_error(y, yHat):
    return np.square(np.subtract(y, yHat)).mean()


def one_hot_encoder(x, output_num):
    result = np.zeros(output_num)
    result[x] = 1
    return result

# %%
def calc_activation(x, weights):
    activations = []
    activation = x.flatten()
    for idx, w in enumerate(weights):
        z = np.dot(w, activation) + biases[idx]
        if idx < len(weights) - 1:
            activation = sigmoid(z)
        else:
            activation = softmax(z)
        activations.append(activation)
    return activations

# %%
def feed_forward_sample(x, y, l1=0.01, l2=0.02):
    activations_arr = calc_activation(x, weights)
    activation = activations_arr[-1]
    one_hot_y = one_hot_encoder(y, output_size)
    loss = cross_entropy_loss(one_hot_y, activation)
    # apply penalties
    for w, b in zip(weights, biases):
        loss += l1 * (np.sum(abs(w)) + np.sum(abs(b))) + l2 * (np.sum((w) ** 2) + np.sum((b) ** 2))

    one_hot_prediction = np.zeros_like(activation)
    one_hot_prediction[np.argmax(activation)] = 1
    return loss, one_hot_prediction


def evaluate_dataset(x, y):
    loss_arr = np.empty(x.shape[0])
    one_hot_predictions = np.empty((x.shape[0], output_size))

    for i in range(x.shape[0]):
        loss_arr[i], one_hot_predictions[i] = feed_forward_sample(x[i], y[i])

    print("Average loss=", np.round(np.average(loss_arr), decimals=2))

    y_one_hot = np.zeros((y.size, output_size))
    y_one_hot[np.arange(y.size), y] = 1

    correct_predictions = np.sum(y_one_hot * one_hot_predictions)
    correct_pred_percent = format((correct_predictions / y.shape[0]) * 100, ".2f")
    print("Accuracy (% of correct predictions):", correct_predictions, "/", y.shape[0], "[", correct_pred_percent, "%]")


def train_one_sample(x, y, lr_rate=0.001, l1=0.01, l2=0.02, momentum=0.9):
    sample = x.flatten()
    activations = calc_activation(sample, weights)
    a = activations[-1]
    one_hot_y = one_hot_encoder(y, output_size)
    # loss = cross_entropy_loss(one_hot_y, sample)
    # # apply penalties
    # for w, b in zip(weights, biases):
    #     loss += l1 * (np.sum(abs(w)) + np.sum(abs(b))) + l2 * (np.sum((w) ** 2) + np.sum((b) ** 2))

    one_hot_guess = np.zeros_like(a)
    one_hot_guess[np.argmax(a)] = 1

    weight_gradients = [None] * len(weights)
    bias_gradients = [None] * len(weights)
    activation_gradients = [None] * (len(weights) - 1)
    # change_w = np.zeros(len(weights))
    # change_b = np.zeros(len(biases))

    for i in reversed(range(len(weights))):

        if i == len(weights) - 1:
            y = one_hot_y.reshape(-1, 1)
            a = activations[i].reshape(-1, 1)
            a_prev = activations[i - 1].reshape(-1, 1)

            weight_gradients[i] = np.dot((a - y), a_prev.T)
            bias_gradients[i] = a - y
        else:
            w_next = weights[i + 1]
            a_next = activations[i + 1].reshape(-1, 1)
            y = one_hot_y.reshape(-1, 1)
            a = activations[i].reshape(-1, 1)
            if i > 0:
                a_prev = activations[i - 1].reshape(-1, 1)
            else:
                a_prev = x.flatten().reshape(-1, 1)

            if i == len(weights) - 2:
                dA = np.dot(w_next.T, (a_next - y))
                activation_gradients[i] = dA
            else:
                dA_next = activation_gradients[i + 1]
                dA = np.dot(w_next.T, (der_sigmoid(a_next) * dA_next))
                activation_gradients[i] = dA

            z = der_sigmoid(a) * dA
            weight_gradients[i] = np.dot(z, a_prev.T)
            bias_gradients[i] = z

        #added dropout
        dropout_vec_b = np.random.binomial(1, dropout_rate[i], size=bias_gradients[i].shape)
        bias_gradients[i] *= dropout_vec_b
        dropout_vec_w = np.random.binomial(1, dropout_rate[i], size=weight_gradients[i].shape)
        weight_gradients[i] *= dropout_vec_w
        
        weights[i] -= weight_gradients[i] * lr_rate
        biases[i] -= bias_gradients[i].flatten() * lr_rate
        
def train_dataset(learning_rate=0.0001):
    for idx in range(x_train.shape[0]):
        train_one_sample(x_train[idx], y_train[idx], learning_rate)

# %%
def train_dataset(learning_rate=0.0001):
    for idx in range(x_train.shape[0]):
        train_one_sample(x_train[idx], y_train[idx], learning_rate)

# %%
def train_test_epoch():
    train_dataset()
    evaluate_dataset(x_test, y_test)

# %%
epochs = 5

for e in range(epochs):
    print("\nEpoch {} / {}".format(e + 1, epochs))
    train_test_epoch()
# Out:
# Epoch 1 / 5
# Average loss= 271.89
# Accuracy (% of correct predictions): 4496.0 / 10000 [ 44.96 %]
#
# Epoch 2 / 5
# Average loss= 971.28
# Accuracy (% of correct predictions): 5677.0 / 10000 [ 56.77 %]
#
# Epoch 3 / 5
# Average loss= 2483.24
# Accuracy (% of correct predictions): 5541.0 / 10000 [ 55.41 %]
#
# Epoch 4 / 5
# Average loss= 5274.02
# Accuracy (% of correct predictions): 5644.0 / 10000 [ 56.44 %]
#
# Epoch 5 / 5
# Average loss= 9848.12
# Accuracy (% of correct predictions): 5839.0 / 10000 [ 58.39 %]

# %%
def train_one_sample(x, y, lr_rate=0.001, l1=0.01, l2=0.02, momentum=0.9):
    sample = x.flatten()
    activations = calc_activation(sample, weights)
    a = activations[-1]
    one_hot_y = one_hot_encoder(y, output_size)
    # loss = cross_entropy_loss(one_hot_y, sample)
    # # apply penalties
    # for w, b in zip(weights, biases):
    #     loss += l1 * (np.sum(abs(w)) + np.sum(abs(b))) + l2 * (np.sum((w) ** 2) + np.sum((b) ** 2))

    one_hot_guess = np.zeros_like(a)
    one_hot_guess[np.argmax(a)] = 1

    weight_gradients = [None] * len(weights)
    bias_gradients = [None] * len(weights)
    activation_gradients = [None] * (len(weights) - 1)
    # change_w = np.zeros(len(weights))
    # change_b = np.zeros(len(biases))

    for i in reversed(range(len(weights))):

        if i == len(weights) - 1:
            y = one_hot_y.reshape(-1, 1)
            a = activations[i].reshape(-1, 1)
            a_prev = activations[i - 1].reshape(-1, 1)

            weight_gradients[i] = np.dot((a - y), a_prev.T)
            bias_gradients[i] = a - y
        else:
            w_next = weights[i + 1]
            a_next = activations[i + 1].reshape(-1, 1)
            y = one_hot_y.reshape(-1, 1)
            a = activations[i].reshape(-1, 1)
            if i > 0:
                a_prev = activations[i - 1].reshape(-1, 1)
            else:
                a_prev = x.flatten().reshape(-1, 1)

            if i == len(weights) - 2:
                dA = np.dot(w_next.T, (a_next - y))
                activation_gradients[i] = dA
            else:
                dA_next = activation_gradients[i + 1]
                dA = np.dot(w_next.T, (der_sigmoid(a_next) * dA_next))
                activation_gradients[i] = dA

            z = der_sigmoid(a) * dA
            weight_gradients[i] = np.dot(z, a_prev.T)
            bias_gradients[i] = z
        
        weights[i] -= weight_gradients[i] * lr_rate
        biases[i] -= bias_gradients[i].flatten() * lr_rate

# %%
epochs = 5

for e in range(epochs):
    print("\nEpoch {} / {}".format(e + 1, epochs))
    train_test_epoch()
# Out:
# Epoch 1 / 5
# Average loss= 17056.94
# Accuracy (% of correct predictions): 6188.0 / 10000 [ 61.88 %]
#
# Epoch 2 / 5
# Average loss= 27839.43
# Accuracy (% of correct predictions): 6390.0 / 10000 [ 63.90 %]
#
# Epoch 3 / 5
# Average loss= 42520.0
# Accuracy (% of correct predictions): 6529.0 / 10000 [ 65.29 %]
#
# Epoch 4 / 5
# Average loss= 61057.9
# Accuracy (% of correct predictions): 6731.0 / 10000 [ 67.31 %]
#
# Epoch 5 / 5
# Average loss= 83224.13
# Accuracy (% of correct predictions): 6806.0 / 10000 [ 68.06 %]

# %% [markdown]
# Conclusion: without dropout model gives better results
